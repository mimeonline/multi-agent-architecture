# %% [markdown]
# # Research Assistant (RAG)
#
# Recherchiert, bewertet Quellen und synthetisiert mit Zitaten und Unsicherheiten.
#
# Ein Assistant beantwortet Wissensfragen über eine eigene Korpus + Live-Quellen, gewichtet Quellen nach Verlässlichkeit, synthetisiert eine Antwort mit Zitaten und gibt offene Unsicherheiten zurück.

# %% [markdown]
# ## Architekturübung
#
# Dieses Notebook ist ein Arbeitsblatt zur Reference Architecture. Es führt nicht gegen ein Modell aus, sondern strukturiert die Entscheidungen, Komponenten und Risiken als ausfüllbare Übung.

# %%
architecture = {
    'slug': "research-assistant",
    'title': "Research Assistant (RAG)",
    'scenario': "Ein Assistant beantwortet Wissensfragen über eine eigene Korpus + Live-Quellen, gewichtet Quellen nach Verlässlichkeit, synthetisiert eine Antwort mit Zitaten und gibt offene Unsicherheiten zurück.",
}
architecture

# %% [markdown]
# ## Nächste Schritte
#
# 1. Öffne die Reference Architecture im Atlas.
# 2. Übertrage die Komponenten auf dein eigenes System.
# 3. Ergänze Risiken, Freigaben und Beobachtbarkeit.
# 4. Verlinke passende Pattern-Notebooks aus dem Implementation Lab.
