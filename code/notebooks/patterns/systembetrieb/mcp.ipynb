# %% [markdown]
# # MCP (Model Context Protocol)
#
# **Domäne:** Systembetrieb / Tool Integration
#
# Tools und Ressourcen werden über MCP standardisiert eingebunden.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. MCP Server verbinden
# 2. Capabilities entdecken
# 3. Tool-Aufrufe über Protokoll ausführen

# %%
import subprocess, sys

prompt = "Expose a filesystem search capability through an MCP-style tool boundary."
cmd = ['agent-patterns', 'run', "mcp", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/mcp.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/mcp.py)
# - CLI: `agent-patterns run mcp "Expose a filesystem search capability through an MCP-style tool boundary."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
