# %% [markdown]
# # Function Calling
#
# **Domäne:** Systembetrieb / Tool Integration
#
# Tools werden über strukturierte, validierbare Argumente aufgerufen.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Schema definieren
# 2. Tool auswählen
# 3. Argumente validieren und ausführen

# %%
import subprocess, sys

prompt = "Calculate subscription cost for 7 seats at 19.5 per seat for 6 months."
cmd = ['agent-patterns', 'run', "function-calling", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/function_calling.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/function_calling.py)
# - CLI: `agent-patterns run function-calling "Calculate subscription cost for 7 seats at 19.5 per seat for 6 months."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
