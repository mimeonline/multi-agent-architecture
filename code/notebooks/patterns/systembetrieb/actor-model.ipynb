# %% [markdown]
# # Actor Model
#
# **Domäne:** Systembetrieb / Runtime
#
# Agents kapseln Zustand und kommunizieren über Nachrichten.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Actor pro Agent starten
# 2. Nachricht senden
# 3. Antwort asynchron sammeln

# %%
import subprocess, sys

prompt = "Send messages between two stateful agent actors."
cmd = ['agent-patterns', 'run', "actor-model", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/actor_model.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/actor_model.py)
# - CLI: `agent-patterns run actor-model "Send messages between two stateful agent actors."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
