# %% [markdown]
# # Graph Memory
#
# **Domäne:** Systembetrieb / Memory
#
# Entitäten und Beziehungen werden als Graph gespeichert.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Entitäten extrahieren
# 2. Kanten aktualisieren
# 3. Antwort über Graphpfade begründen

# %%
import subprocess, sys

prompt = "Model relationships between agents, tools, and permissions."
cmd = ['agent-patterns', 'run', "graph-memory", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/graph_memory.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/graph_memory.py)
# - CLI: `agent-patterns run graph-memory "Model relationships between agents, tools, and permissions."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
