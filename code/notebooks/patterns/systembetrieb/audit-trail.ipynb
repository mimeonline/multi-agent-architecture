# %% [markdown]
# # Audit Trail
#
# **Domäne:** Systembetrieb / Governance
#
# Entscheidungen und Tool-Aufrufe werden nachvollziehbar protokolliert.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Run-ID erzeugen
# 2. Events loggen
# 3. Trace für Review speichern

# %%
import subprocess, sys

prompt = "Record tool calls and approvals for later review."
cmd = ['agent-patterns', 'run', "audit-trail", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/audit_trail.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/audit_trail.py)
# - CLI: `agent-patterns run audit-trail "Record tool calls and approvals for later review."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
