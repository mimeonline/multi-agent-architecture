# %% [markdown]
# # Event-driven Choreography
#
# **Domäne:** Systembetrieb / Runtime
#
# Komponenten reagieren auf Ereignisse statt auf zentrale Steuerung.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Event publizieren
# 2. Subscriber reagieren
# 3. Folgeevents erzeugen

# %%
import subprocess, sys

prompt = "React to a new support ticket event with independent handlers."
cmd = ['agent-patterns', 'run', "event-driven-choreography", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/event_driven_choreography.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/event_driven_choreography.py)
# - CLI: `agent-patterns run event-driven-choreography "React to a new support ticket event with independent handlers."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
