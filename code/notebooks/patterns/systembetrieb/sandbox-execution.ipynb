# %% [markdown]
# # Sandbox Execution
#
# **Domäne:** Systembetrieb / Governance
#
# Code oder Aktionen laufen isoliert mit begrenzten Rechten.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Code prüfen
# 2. Sandbox mit Limits starten
# 3. Output ohne Seiteneffekte auswerten

# %%
import subprocess, sys

prompt = "Run generated code in a restricted sandbox."
cmd = ['agent-patterns', 'run', "sandbox-execution", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/systembetrieb/sandbox_execution.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/systembetrieb/sandbox_execution.py)
# - CLI: `agent-patterns run sandbox-execution "Run generated code in a restricted sandbox."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
