# %% [markdown]
# # Self-Consistency
#
# **Domäne:** Denken
#
# Mehrere unabhängige Antworten werden erzeugt und per Konsens zusammengeführt.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Mehrere unabhängige Samples mit leicht unterschiedlicher Perspektive erzeugen
# 2. Antworten normalisieren und gruppieren
# 3. Mehrheits- oder Konsensantwort zurückgeben

# %%
import subprocess, sys

prompt = "Answer whether a lightweight router or supervisor is better for support triage."
cmd = ['agent-patterns', 'run', "self-consistency", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/denken/self_consistency.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/denken/self_consistency.py)
# - CLI: `agent-patterns run self-consistency "Answer whether a lightweight router or supervisor is better for support triage."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
