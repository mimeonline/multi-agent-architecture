# %% [markdown]
# # ReAct
#
# **Domäne:** Denken
#
# Der Agent wechselt iterativ zwischen Reasoning, Tool-Aufruf und Beobachtung.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %% [markdown]
# ## Modellzugang in Colab
#
# GitHub oder Colab stellen keinen Model-Token automatisch bereit. Ohne eigenen Token läuft die Demo im erklärenden Offline-Modus. Für echte Modellantworten kannst du GitHub Models nutzen, weil der Endpoint OpenAI-kompatibel ist. Füge bei Bedarf vor dem Demo-Run eine Code-Zelle mit diesem Inhalt ein:
#
# ```python
# import getpass
# import os
#
# os.environ["AGENT_PROVIDER"] = "github"
# os.environ["GITHUB_TOKEN"] = getpass.getpass("GitHub Token mit Models-Zugriff: ")
# os.environ["GITHUB_MODEL"] = "openai/gpt-4.1-mini"
# ```
#
# Der Token braucht Zugriff auf GitHub Models, in der Regel `models:read`.

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')
# Out:
# Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.

# %% [markdown]
# ## Ablauf
#
# 1. Demo öffnen
# 2. Run-Befehl ausführen
# 3. Output und Pattern-Mechanik vergleichen

# %%
import subprocess, sys

prompt = "Find 12 * 7 and summarize the tool result."
cmd = ['agent-patterns', 'run', "react", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)
# Out:
# $ agent-patterns run react Find 12 * 7 and summarize the tool result.
# Pattern: ReAct
# Mode: online provider failed (github: AuthenticationError: Unauthorized)
# Thought: still demonstrate the ReAct loop for: Find 12 * 7 and summarize the tool result.
# Tool calculator('12 * 7'): 84
# Tool tiny_search('LangGraph handoff'): LangGraph models agent workflows as stateful graphs. Handoffs transfer control from one specialized agent to another.
# Answer: combine tool observations before responding to the user.

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/denken/react.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/denken/react.py)
# - CLI: `agent-patterns run react "Find 12 * 7 and summarize the tool result."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
