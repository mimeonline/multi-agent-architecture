# %% [markdown]
# # Parallelization (Voting)
#
# **Domäne:** Ablauf
#
# Mehrere Läufe bearbeiten dieselbe Aufgabe und ein Aggregator wählt das beste Ergebnis.
#
# Dieses Notebook ist ein dünner Lernpfad über dem Python-Package. Die ausführbare Wahrheit bleibt im Package, damit Tests, CLI und Webapp dieselbe Demo verwenden.

# %% [markdown]
# ## Lernfrage
#
# - Welche Architekturidee zeigt das Pattern?
# - Welche Schritte gehören zum Ablauf?
# - Wie verändert sich der Output mit einem echten Modell-Key?

# %%
import sys, subprocess

if 'google.colab' in sys.modules:
    subprocess.run([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'git+https://github.com/mimeonline/multi-agent-architecture.git#subdirectory=code',
    ], check=True)
else:
    print('Lokal: aus dem Repo-Root `pip install -e code` ausführen, falls das Package noch nicht installiert ist.')

# %% [markdown]
# ## Ablauf
#
# 1. Drei Kandidaten generieren
# 2. Kandidaten bewerten
# 3. Gewinner oder Synthese zurückgeben

# %%
import subprocess, sys

prompt = "Choose the best short title for an AI agent pattern guide."
cmd = ['agent-patterns', 'run', "parallelization-voting", prompt]
print('$ ' + ' '.join(cmd))
completed = subprocess.run(cmd, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr, file=sys.stderr)

# %% [markdown]
# ## Weiterarbeiten
#
# - Quelle: [code/src/ai_agent_patterns/demos/ablauf/parallelization_voting.py](https://github.com/mimeonline/multi-agent-architecture/blob/main/code/src/ai_agent_patterns/demos/ablauf/parallelization_voting.py)
# - CLI: `agent-patterns run parallelization-voting "Choose the best short title for an AI agent pattern guide."`
# - Passe `prompt` in der vorherigen Zelle an, um Varianten des Patterns zu testen.
